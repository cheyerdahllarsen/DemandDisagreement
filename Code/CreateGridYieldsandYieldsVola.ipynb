# %% [markdown]
# This code creates a grid on $f$ and $\alpha$ for yields and yield volatilities for a set of maturities taus. The set of results is stored in a file in the local `Data/Model Disagreement` folder and can be directly used in other programs.
#
# **Note: This notebook has been modified to run locally instead of on Google Colab.**

# %% [markdown]
# Importing liberaries

# %%
import torch
import time
import numpy as np
import matplotlib.pyplot as plt
import gc
import pandas as pd
import hashlib
import os

# %% [markdown]
# Creating a function to make unique files names for different paramter values

# %%
# Function to generate a hash from parameters
def generate_filename_hash(pars):
    # Convert parameters to a string and then to a hash
    pars_str = '_'.join(map(str, pars))
    return hashlib.md5(pars_str.encode()).hexdigest()[:8]  # U

# %% [markdown]
# Defining the basic yield function. This calculates the yields by Monte-Carlo simulations on the GPU using PyTorch

# %%
def getYield(f, l, tau, pars, M, dt, device):
    rhoA, rhoB, nu, DEL, kap, lbar, sig_l, muY, sigY = pars

    NT = round(tau / dt) #Number of time steps

    # Initialize tensors for all paths
    ft = f * torch.ones(M, device=device)
    lt = l * torch.ones(M, device=device)
    DFt = torch.ones(M, device=device)

    # Generate random numbers for all paths and time steps
    dZ = torch.sqrt(torch.tensor(dt)) * torch.randn(NT, M, device=device)

    for i in range(NT):
        theta_alp = DEL * (0.5 - ft)
        alpt = 1 / (1 + torch.exp(-lt))
        phit = ft / (rhoA + nu) + (1 - ft) / (rhoB + nu)
        betAt = (rhoA + nu) * phit
        betBt = (rhoB + nu) * phit

        muft = nu * (alpt * betAt * (1 - ft) - (1 - alpt) * betBt * ft) + (rhoB - rhoA) * ft * (1 - ft) + DEL**2 * (1/2 - ft) * ft * (1 - ft)
        sigft = ft * (1 - ft) * DEL
        dft = muft * dt + sigft * (dZ[i, :] - theta_alp * dt)
        dlt = kap * (lbar - lt) * dt + sig_l * (dZ[i, :] - theta_alp * dt)

        lt =lt + dlt  # update l0
        ft =ft + dft  # update f0
        rbar = muY - sigY**2
        r = rbar + rhoA * ft + rhoB * (1 - ft)  + nu * (1 - alpt * betAt - (1 - alpt) * betBt)
        DFt *= torch.exp(-r * dt)

    B = torch.mean(DFt)
    return -torch.log(B) / tau

# %% [markdown]
# A function that caluclates the yield and yield volatilities by using Monte-Carlo simulations (the getYield code above) and automatic differentiation

# %%
def getYieldandYieldVola(f, alp, tau, pars, M, dt, device):
  rhoA, rhoB, nu, DEL, kap, lbar, sig_l, muY, sigY = pars
  #Since we are doing autodiff we need to make sure we have enabled autograd
  l = -np.log(1/alp-1)
  lt = torch.tensor([l], device=device, requires_grad=True)  # Example value
  ft = torch.tensor([f], device=device, requires_grad=True)  # Example value
  #Calculating the yield
  y = getYield(ft, lt, tau, pars, M, dt, device)
  # Compute gradients
  y.backward()
  sigY = ft.grad.item()*ft*(1-ft)*DEL+lt.grad.item()*sig_l
  return y.item(), sigY.item(), ft.grad.item(), lt.grad.item()

# %% [markdown]
# Creating a function that return the results for a series of maturities

# %%
def getAllMaturities(f, alp, taus, pars, M, dt, device):
  results = []
  for tau in taus:
    partCalc = []
    y, sigY, _, _ = getYieldandYieldVola(f, alp, tau, pars, M, dt, device)
    results.append(y)
    results.append(sigY)
  return results

# %% [markdown]
# Creating the function that saves the results

# %%
# Create the Grid and Calculate Output
def calculate_and_save_results(f_values, alpha_values, pars):
    # Create the output directory if it doesn't exist
    output_dir = 'Data/Model Disagreement'
    os.makedirs(output_dir, exist_ok=True)
    
    results = []
    for f in f_values:
      for alp in alpha_values:
        output = getAllMaturities(f, alp, taus, pars, M, dt, device) # assuming pars is defined
        results.append([f, alp, *output, *pars])
        print(f'the f value is {f} and the alpha is {alp}')
    # Check the length of the output and adjust columns accordingly
    if len(results) > 0:
        num_output_elements = len(results[0]) - 2 - len(pars)  # f, alpha, and pars are excluded

    # Columns for DataFrame
    columns = ['f', 'alpha'] + [f'result_{i}' for i in range(num_output_elements)] + [f'par_{i}' for i in range(len(pars))]

    # Ensure the number of columns matches the data
    assert len(columns) == len(results[0]), "Column count does not match data length."

    df = pd.DataFrame(results, columns=columns)

    # Save to local directory
    filename_hash = generate_filename_hash(pars)
    file_path = os.path.join(output_dir, f'resultsTEST_{filename_hash}.csv')
    df.to_csv(file_path, index=False)

    print(f"Data saved to local directory with filename: resultsLong_{filename_hash}.csv")
    print(f"Full path: {file_path}")

# %% [markdown]
# Here we set up the specific enivornment for Pytorch.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# Setting up the hyperparameters such as monte-carlo paths and time steps

# %%
dt = 1 / 12
M = 1000  # Number of paths. #Use 500000 for the paper.

# %% [markdown]
# Setting up the model parameters. Note that this is the baseline version of the mode. We might have to extend to real disagreement (gdp) and timevarying disagreement ($\Delta$ being stochastic).

# %%
DEL = 0.1
rhoA = 0.001
rhoB = 0.05
nu = 0.02
kap = 0.01
lbar = 0
sig_l = 0.1
muY = 0.02
sigY = 0.033
pars = [rhoA , rhoB, nu, DEL, kap, lbar, sig_l, muY, sigY]

# %% [markdown]
# Creating the grid

# %%
taus = [1, 2, 3, 4, 5, 7, 10]

# %%
f_min = 0.001
f_max = 1 - f_min
alp_min = 0.001
alp_max = 1 - alp_min
f_steps = 100
alp_steps = 100

# %%
# Step 1: Create the Grid
f_values = np.linspace(f_min, f_max, num=f_steps) # Define f_min, f_max, f_steps
alpha_values = np.linspace(alp_min, alp_max, num=alp_steps) # Define alpha_min, alpha_max, alpha_steps

# %%
calculate_and_save_results(f_values, alpha_values, pars)
# Out:
# the f value is 0.001 and the alpha is 0.001
# the f value is 0.001 and the alpha is 0.01108080808080808
# the f value is 0.001 and the alpha is 0.021161616161616163
# the f value is 0.001 and the alpha is 0.031242424242424245
# the f value is 0.001 and the alpha is 0.041323232323232324
# the f value is 0.001 and the alpha is 0.0514040404040404
# the f value is 0.001 and the alpha is 0.06148484848484849
# the f value is 0.001 and the alpha is 0.07156565656565657
# the f value is 0.001 and the alpha is 0.08164646464646465
# the f value is 0.001 and the alpha is 0.09172727272727273
# the f value is 0.001 and the alpha is 0.1018080808080808
# the f value is 0.001 and the alpha is 0.11188888888888888
# the f value is 0.001 and the alpha is 0.12196969696969698
# the f value is 0.001 and the alpha is 0.13205050505050506
# the f value is 0.001 and the alpha is 0.14213131313131314
# the f value is 0.001 and the alpha is 0.15221212121212122
# the f value is 0.001 and the alpha is 0.1622929292929293
# the f value is 0.001 and the alpha is 0.17237373737373737
# the f value is 0.001 and the alpha is 0.18245454545454545
# the f value is 0.001 and the alpha is 0.19253535353535353
# the f value is 0.001 and the alpha is 0.2026161616161616
# the f value is 0.001 and the alpha is 0.2126969696969697
# the f value is 0.001 and the alpha is 0.22277777777777777
# the f value is 0.001 and the alpha is 0.23285858585858585
# the f value is 0.001 and the alpha is 0.24293939393939395
# the f value is 0.001 and the alpha is 0.25302020202020203
# the f value is 0.001 and the alpha is 0.2631010101010101
# the f value is 0.001 and the alpha is 0.2731818181818182
# the f value is 0.001 and the alpha is 0.28326262626262627
# the f value is 0.001 and the alpha is 0.29334343434343435
# the f value is 0.001 and the alpha is 0.30342424242424243
# the f value is 0.001 and the alpha is 0.3135050505050505
# the f value is 0.001 and the alpha is 0.3235858585858586
# the f value is 0.001 and the alpha is 0.33366666666666667
# the f value is 0.001 and the alpha is 0.34374747474747475
# the f value is 0.001 and the alpha is 0.3538282828282828
# the f value is 0.001 and the alpha is 0.3639090909090909
# the f value is 0.001 and the alpha is 0.373989898989899
# the f value is 0.001 and the alpha is 0.38407070707070706
# the f value is 0.001 and the alpha is 0.39415151515151514
# the f value is 0.001 and the alpha is 0.4042323232323232
# the f value is 0.001 and the alpha is 0.4143131313131313
# the f value is 0.001 and the alpha is 0.4243939393939394
# the f value is 0.001 and the alpha is 0.43447474747474746
# the f value is 0.001 and the alpha is 0.44455555555555554
# the f value is 0.001 and the alpha is 0.4546363636363636
# the f value is 0.001 and the alpha is 0.4647171717171717
# the f value is 0.001 and the alpha is 0.4747979797979798
# the f value is 0.001 and the alpha is 0.4848787878787879
# the f value is 0.001 and the alpha is 0.494959595959596
# the f value is 0.001 and the alpha is 0.5050404040404041
# the f value is 0.001 and the alpha is 0.5151212121212121
# the f value is 0.001 and the alpha is 0.5252020202020202
# the f value is 0.001 and the alpha is 0.5352828282828282
# the f value is 0.001 and the alpha is 0.5453636363636364
# the f value is 0.001 and the alpha is 0.5554444444444444
# the f value is 0.001 and the alpha is 0.5655252525252525
# the f value is 0.001 and the alpha is 0.5756060606060606
# the f value is 0.001 and the alpha is 0.5856868686868687
# the f value is 0.001 and the alpha is 0.5957676767676767
# the f value is 0.001 and the alpha is 0.6058484848484849
# the f value is 0.001 and the alpha is 0.6159292929292929
# the f value is 0.001 and the alpha is 0.626010101010101
# the f value is 0.001 and the alpha is 0.636090909090909
# the f value is 0.001 and the alpha is 0.6461717171717172
# the f value is 0.001 and the alpha is 0.6562525252525253
# the f value is 0.001 and the alpha is 0.6663333333333333
# the f value is 0.001 and the alpha is 0.6764141414141415
# the f value is 0.001 and the alpha is 0.6864949494949495
# the f value is 0.001 and the alpha is 0.6965757575757576
# the f value is 0.001 and the alpha is 0.7066565656565656
# the f value is 0.001 and the alpha is 0.7167373737373738
# the f value is 0.001 and the alpha is 0.7268181818181818
# the f value is 0.021161616161616163 and the alpha is 0.2731818181818182
# the f value is 0.021161616161616163 and the alpha is 0.28326262626262627
# the f value is 0.021161616161616163 and the alpha is 0.29334343434343435
# the f value is 0.021161616161616163 and the alpha is 0.30342424242424243
# the f value is 0.021161616161616163 and the alpha is 0.3135050505050505
# the f value is 0.021161616161616163 and the alpha is 0.3235858585858586
# the f value is 0.021161616161616163 and the alpha is 0.33366666666666667
# the f value is 0.021161616161616163 and the alpha is 0.34374747474747475
# the f value is 0.021161616161616163 and the alpha is 0.3538282828282828
# the f value is 0.021161616161616163 and the alpha is 0.3639090909090909
# the f value is 0.021161616161616163 and the alpha is 0.373989898989899
# the f value is 0.021161616161616163 and the alpha is 0.38407070707070706
# the f value is 0.021161616161616163 and the alpha is 0.39415151515151514
# the f value is 0.021161616161616163 and the alpha is 0.4042323232323232
# the f value is 0.021161616161616163 and the alpha is 0.4143131313131313
# the f value is 0.021161616161616163 and the alpha is 0.4243939393939394
# the f value is 0.021161616161616163 and the alpha is 0.43447474747474746
# the f value is 0.021161616161616163 and the alpha is 0.44455555555555554
# the f value is 0.021161616161616163 and the alpha is 0.4546363636363636
# the f value is 0.021161616161616163 and the alpha is 0.4647171717171717
# the f value is 0.021161616161616163 and the alpha is 0.4747979797979798
# the f value is 0.021161616161616163 and the alpha is 0.4848787878787879
# the f value is 0.021161616161616163 and the alpha is 0.494959595959596
# the f value is 0.021161616161616163 and the alpha is 0.5050404040404041
# the f value is 0.021161616161616163 and the alpha is 0.5151212121212121
# the f value is 0.021161616161616163 and the alpha is 0.5252020202020202
# the f value is 0.021161616161616163 and the alpha is 0.5352828282828282
# the f value is 0.021161616161616163 and the alpha is 0.5453636363636364
# the f value is 0.021161616161616163 and the alpha is 0.5554444444444444
# the f value is 0.021161616161616163 and the alpha is 0.5655252525252525
# the f value is 0.021161616161616163 and the alpha is 0.5756060606060606
# the f value is 0.021161616161616163 and the alpha is 0.5856868686868687
# the f value is 0.021161616161616163 and the alpha is 0.5957676767676767
# the f value is 0.021161616161616163 and the alpha is 0.6058484848484849
# the f value is 0.021161616161616163 and the alpha is 0.6159292929292929
# the f value is 0.021161616161616163 and the alpha is 0.626010101010101
# the f value is 0.021161616161616163 and the alpha is 0.636090909090909
# the f value is 0.021161616161616163 and the alpha is 0.6461717171717172
# the f value is 0.021161616161616163 and the alpha is 0.6562525252525253
# the f value is 0.021161616161616163 and the alpha is 0.6663333333333333
# the f value is 0.021161616161616163 and the alpha is 0.6764141414141415
# the f value is 0.021161616161616163 and the alpha is 0.6864949494949495
# the f value is 0.021161616161616163 and the alpha is 0.6965757575757576
# the f value is 0.021161616161616163 and the alpha is 0.7066565656565656
# the f value is 0.021161616161616163 and the alpha is 0.7167373737373738
# the f value is 0.021161616161616163 and the alpha is 0.7268181818181818
# the f value is 0.021161616161616163 and the alpha is 0.7368989898989899
# the f value is 0.021161616161616163 and the alpha is 0.746979797979798
# the f value is 0.021161616161616163 and the alpha is 0.7570606060606061
# the f value is 0.999 and the alpha is 0.43447474747474746
# the f value is 0.999 and the alpha is 0.44455555555555554
# the f value is 0.999 and the alpha is 0.4546363636363636
# the f value is 0.999 and the alpha is 0.4647171717171717
# the f value is 0.999 and the alpha is 0.4747979797979798
# the f value is 0.999 and the alpha is 0.4848787878787879
# the f value is 0.999 and the alpha is 0.494959595959596
# the f value is 0.999 and the alpha is 0.5050404040404041
# the f value is 0.999 and the alpha is 0.5151212121212121
# the f value is 0.999 and the alpha is 0.5252020202020202
# the f value is 0.999 and the alpha is 0.5352828282828282
# the f value is 0.999 and the alpha is 0.5453636363636364
# the f value is 0.999 and the alpha is 0.5554444444444444
# the f value is 0.999 and the alpha is 0.5655252525252525
# the f value is 0.999 and the alpha is 0.5756060606060606
# the f value is 0.999 and the alpha is 0.5856868686868687
# the f value is 0.999 and the alpha is 0.5957676767676767
# the f value is 0.999 and the alpha is 0.6058484848484849
# the f value is 0.999 and the alpha is 0.6159292929292929
# the f value is 0.999 and the alpha is 0.626010101010101
# the f value is 0.999 and the alpha is 0.636090909090909
# the f value is 0.999 and the alpha is 0.6461717171717172
# the f value is 0.999 and the alpha is 0.6562525252525253
# the f value is 0.999 and the alpha is 0.6663333333333333
# the f value is 0.999 and the alpha is 0.6764141414141415
# the f value is 0.999 and the alpha is 0.6864949494949495
# the f value is 0.999 and the alpha is 0.6965757575757576
# the f value is 0.999 and the alpha is 0.7066565656565656
# the f value is 0.999 and the alpha is 0.7167373737373738
# the f value is 0.999 and the alpha is 0.7268181818181818
# the f value is 0.999 and the alpha is 0.7368989898989899
# the f value is 0.999 and the alpha is 0.746979797979798
# the f value is 0.999 and the alpha is 0.7570606060606061
# the f value is 0.999 and the alpha is 0.7671414141414141
# the f value is 0.999 and the alpha is 0.7772222222222223
# the f value is 0.999 and the alpha is 0.7873030303030303
# the f value is 0.999 and the alpha is 0.7973838383838384
# the f value is 0.999 and the alpha is 0.8074646464646464
# the f value is 0.999 and the alpha is 0.8175454545454546
# the f value is 0.999 and the alpha is 0.8276262626262626
# the f value is 0.999 and the alpha is 0.8377070707070707
# the f value is 0.999 and the alpha is 0.8477878787878788
# the f value is 0.999 and the alpha is 0.8578686868686869
# the f value is 0.999 and the alpha is 0.8679494949494949
# the f value is 0.999 and the alpha is 0.878030303030303
# the f value is 0.999 and the alpha is 0.8881111111111111
# the f value is 0.999 and the alpha is 0.8981919191919192
# the f value is 0.999 and the alpha is 0.9082727272727272
# the f value is 0.999 and the alpha is 0.9183535353535354
# the f value is 0.999 and the alpha is 0.9284343434343434
# the f value is 0.999 and the alpha is 0.9385151515151515
# the f value is 0.999 and the alpha is 0.9485959595959595
# the f value is 0.999 and the alpha is 0.9586767676767677
# the f value is 0.999 and the alpha is 0.9687575757575758
# the f value is 0.999 and the alpha is 0.9788383838383838
# the f value is 0.999 and the alpha is 0.988919191919192
# the f value is 0.999 and the alpha is 0.999
# Data saved to local directory with filename: resultsLong_07b6a91a.csv
# Full path: Data/Model Disagreement\resultsTEST_07b6a91a.csv
